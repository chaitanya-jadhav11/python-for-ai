# %%
2==2
# Out:
# True

# %%
2==1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %%
'2' == 2
# Out:
# False

# %%
2.0 ==2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
2 <= 2
# Out:
# True
