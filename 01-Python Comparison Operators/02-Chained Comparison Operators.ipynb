# %%
 1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
'h' == 'h' and 2 ==2
# Out:
# True

# %%
('h' == 'h') and (2 ==2)
# Out:
# True

# %%
('h' == 'h') or (2 ==1)
# Out:
# True

# %%
'h' == 'h' or  2 ==1
# Out:
# True

# %%
not 1==1
# Out:
# False

# %%
not (1 ==1)
# Out:
# False
