# %%
x = [1,3,4]
y = 2
z = 3

result = y + z
print(result)
result2 = y+x
print(result2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 result = y + z
#       6 print(result)
# ----> 7 result2 = y+x
#       8 print(result2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
import pdb

x = [1,3,4]
y = 2
z = 3

result1 = y + z
pdb.set_trace() # inspect variable values
result2 = y+x
# Out:
# > c:\users\admin\appdata\local\temp\ipykernel_15444\664641570.py(8)<module>()
# ipdb>  y+x
# *** TypeError: unsupported operand type(s) for +: 'int' and 'list'
# ipdb>  q
