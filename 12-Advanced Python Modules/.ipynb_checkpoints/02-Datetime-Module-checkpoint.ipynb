# %%
import datetime
mytime = datetime.time(13,20,1,20)

# %%
mytime.hour
# Out:
# 13

# %%
mytime.minute
# Out:
# 20

# %%
mytime.second
# Out:
# 1

# %%
print(mytime)
# Out:
# 13:20:01.000020

# %%
today = datetime.date.today()

# %%
print (today)
# Out:
# 2026-02-13

# %%
today.year
# Out:
# 2026

# %%
today.ctime()
# Out:
# 'Fri Feb 13 00:00:00 2026'

# %%
from  datetime import datetime

# %%
mydate = datetime(2021,10,3,14,20,1)

# %%
mydate
# Out:
# datetime.datetime(2021, 10, 3, 14, 20, 1)

# %%
mydate.replace(year=2026)
# Out:
# datetime.datetime(2026, 10, 3, 14, 20, 1)

# %%
#Compare
from  datetime import date
date1 = date (2021,11,3)
date2 = date (2026,11,3)
diff = date1 - date2
print (diff)
# Out:
# -1826 days, 0:00:00

# %%
d1= datetime(2021, 10, 3, 14, 20, 1)
d2= datetime(2026, 10, 3, 14, 20, 1)
d3= d2-d1
print (d3.total_seconds())
# Out:
# 157766400.0
