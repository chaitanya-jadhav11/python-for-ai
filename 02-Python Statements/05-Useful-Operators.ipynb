# %%
#Range

for num in range(3,10,2):
    print (num)
# Out:
# 3
# 5
# 7
# 9

# %%
list(range(0,11,2))
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
list
# Out:
# range(3, 10, 2)

# %% [markdown]
# Index

# %%
indexCount=0
str ='abcde'
for c in str:    
    print('indext {}  char {} '.format(indexCount, str[indexCount]));
    indexCount= indexCount+1
# Out:
# indext 0  char a
# indext 1  char b
# indext 2  char c
# indext 3  char d
# indext 4  char e

# %%
word ='abcde'

for item in enumerate(word):
    print (item)
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')
# (3, 'd')
# (4, 'e')

# %%
word ='abcde'

for idex,value in enumerate(word):
    print (idex)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ZIP

# %%
mylist1 = [1,2,3,4,5,6]
mylist2 = ['a','b','c','d','e', 'f']
mylist3 = [10,20,30,40,50,60]

zip(mylist1,mylist2)

# %%
for item in zip(mylist1,mylist2, mylist3):
    print (item)
# Out:
# (1, 'a', 10)
# (2, 'b', 20)
# (3, 'c', 30)
# (4, 'd', 40)
# (5, 'e', 50)
# (6, 'f', 60)

# %%
myNewList = zip(mylist1,mylist2, mylist3)

# %%
myNewList

# %% [markdown]
# Item check in List

# %%
'x' in (1,2,3)
# Out:
# False

# %%
'x' in ('x',2,3)
# Out:
# True

# %%
'a ' in 'a hi'
# Out:
# True

# %%
'mykey' in {'myKey': 1} # Case sensitive
# Out:
# False

# %%
'mykey' in {'mykey': 1} # Case sensitive
# Out:
# True

# %%
'mykey' in {'mykey': 1} # Case sensitive
# Out:
# True

# %% [markdown]
#      Min / max

# %%
mylist = [10,20,30,40,100]

# %%
max(mylist)
# Out:
# 100

# %%
min(mylist)
# Out:
# 10

# %%
from random import shuffle
mylist = [10,20,30,40,100]
randomList = shuffle(mylist)

# %%
print (randomList)
# Out:
# None

# %%
from random import randint
randint(1,33)
# Out:
# 5

# %% [markdown]
# INPUT

# %%
num = input('enter number')
# Out:
# enter number 3

# %%
num
# Out:
# '3'
