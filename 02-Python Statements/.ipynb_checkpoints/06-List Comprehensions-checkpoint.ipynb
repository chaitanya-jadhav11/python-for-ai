# %%
myString = 'hello'

# %%
mylist = []

for letter in myString:
    mylist.append(letter)

# %%
mylist
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#Alternative to abovo code

# %%
mylist = [letter2 for letter2 in myString]

# %%
mylist
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
mylist = [x for x in range (1,10)]

# %%
mylist
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# find sq of each random num
mylist = [x**2 for x in range (1,10)]
mylist
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# find sq of each random num with some condition
mylist = [x**2 for x in range (1,10) if x % 2==0]
mylist
# Out:
# [4, 16, 36, 64]
