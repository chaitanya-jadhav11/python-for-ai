# %%
x= 0

while x < 5 :
    x= x+1
    print (x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x =[1,2,3] # PASS

for item in x:
    pass

# %%
# continue
myStr= 'Sammy'

for c in myStr:
    if c =='a':
        continue
    print (c)
# Out:
# S
# m
# m
# y

# %%
# Break
myStr= 'Sammy'

for c in myStr:
    if c =='a':
        break
    print (c)
# Out:
# S
