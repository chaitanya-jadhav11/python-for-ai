# %%
if True:
    print('Its true')
# Out:
# Its true

# %%
if 3 > 2:
    print('Its true')
# Out:
# Its true

# %%
hungry = False

if hungry == True:
    print('Feed me')
else:
    print ('Im full')
# Out:
# Im full

# %%
if hungry: # direct use of boolean variable
    print('Feed me')
else:
    print ('Im full')
# Out:
# Im full

# %%
loc= 'Auto Shop'

if loc=='Auto Shop':
    print ('Cars are cool')
elif loc == 'Bank':
    print ('Money is cool')
else:
    print ('I dont know')
# Out:
# Cars are cool
