# %%
s = 'hello world'

# %%
s.capitalize()  # Changing case
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.count('o') # returns the number of occurrences, without overlap
# Out:
# 2

# %%
s.find('o') # returns the starting index position of the first occurence
# Out:
# 4

# %%
s.center(20,'z') # Formatting
# Out:
# 'zzzzhello worldzzzzz'

# %%
s = 'hello'

# %%
s.isalnum() # isalnum() will return True if all characters in s are alphanumeric
# Out:
# True

# %%
s.isspace() # check space
# Out:
# False

# %%
s.split('e') # Built-in Reg. Expressions
# Out:
# ['h', 'llo']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo')
