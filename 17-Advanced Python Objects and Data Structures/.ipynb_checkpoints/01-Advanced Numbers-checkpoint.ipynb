# %% [markdown]
# ### Hexadecimal

# %%
hex(246)
# Out:
# '0xf6'

# %% [markdown]
# ### Binary

# %%
bin(1234)
# Out:
# '0b10011010010'

# %% [markdown]
# ### Exponentials

# %%
pow(3,4)
# Out:
# 81

# %%
pow(3,4,5)
# Out:
# 1

# %% [markdown]
# ### Absolute Value

# %%
abs(-3.14)
# Out:
# 3.14

# %% [markdown]
# ### Round

# %%
round(395.55)
# Out:
# 396
