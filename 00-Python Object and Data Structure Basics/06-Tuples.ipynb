# %% [markdown]
# Tuples

# %%
t = (1,2,3)

# %%
t
# Out:
# (1, 2, 3)

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 3

# %%
t = (1,2,'3')

# %%
t[1] # Similar to List
# Out:
# 2

# %%
t.count(3)
# Out:
# 0

# %%
t.index('3')
# Out:
# 2

# %% [markdown]
# Immutability

# %%
t[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t[0]=1
#
# TypeError: 'tuple' object does not support item assignment
