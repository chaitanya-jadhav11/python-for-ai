# %%
my_list =[1,2,3]

# %%
my_list =["STRING",2.3,3]

# %%
len(my_list)
# Out:
# 3

# %%
my_list =["ONE","TWO","THREE"]

# %%
my_list[1:]
# Out:
# ['TWO', 'THREE']

# %%
my_list2 =my_list

# %%
my_list2
# Out:
# ['ONE', 'TWO', 'THREE']

# %%
my_list2.append('FOUR')

# %%
my_list2
# Out:
# ['ONE', 'TWO', 'THREE', 'FOUR']

# %%
popped_item= my_list2.pop()

# %%
my_list2
# Out:
# ['ONE', 'TWO']

# %%
popped_item
# Out:
# 'THREE'

# %%
popped_item= my_list2.pop(0)

# %%
popped_item
# Out:
# 'ONE'

# %%
my_list =['a','c','b','e','x']

# %%
my_list.sort();

# %%
my_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
my_list.reverse()

# %%
my_list
# Out:
# ['x', 'e', 'c', 'b', 'a']
