# %%
4*4
# Out:
# 16

# %%
3/2
# Out:
# 1.5

# %%
2+1
# Out:
# 3

# %% [markdown]
# Modulo or Mod

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %% [markdown]
# Power

# %%
2 ** 3
# Out:
# 8

# %%
2+10*10-2
# Out:
# 100

# %%
(2+10) * 10
# Out:
# 120
