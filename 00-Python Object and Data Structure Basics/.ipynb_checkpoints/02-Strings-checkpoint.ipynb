# %%
mystr = 'hi'

# %%
mystr = " I'm going to run"

# %%
mystr = "hello"

# %%
mystr[1]
# Out:
# 'e'

# %%
mystr[-1]
# Out:
# 'o'

# %%
mystr[0]
# Out:
# 'h'

# %%
mystr[-4]
# Out:
# 'e'

# %%
print (mystr + ' there ')
# Out:
# hello there

# %%
len (mystr)
# Out:
# 5

# %%
len ("hello there")
# Out:
# 11
