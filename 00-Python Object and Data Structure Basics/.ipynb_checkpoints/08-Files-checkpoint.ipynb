# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# this is second line
# this is third line
# Out:
# Overwriting test.txt

# %%
myfile = open ('test.txt')

# %%
myfile.name
# Out:
# 'test.txt'

# %%
pwd
# Out:
# 'C:\\Gen_AI_workspace\\python-for-ai\\00-Python Object and Data Structure Basics'

# %%
myfile = open ('test.txt')

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nthis is second line\nthis is third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nthis is second line\nthis is third line\n'

# %%
type(myfile)
# Out:
# _io.TextIOWrapper

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'this is second line\n',
#  'this is third line\n']

# %%
myfile = open ("C:\\Gen_AI_workspace\\python-for-ai\\00-Python Object and Data Structure Basics\\test.txt")

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nthis is second line\nthis is third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.close()

# %%
with open ("C:\\Gen_AI_workspace\\python-for-ai\\00-Python Object and Data Structure Basics\\test.txt") as my_new_file:
    content = my_new_file.read() # No need to close file

# %%
content
# Out:
# 'Hello, this is a quick test file.\nthis is second line\nthis is third line\n'

# %%
with open ('test.txt', mode='r' ) as myfile: # read mode
    content = myfile.read()

# %%
# %%writefile my_new_file.txt
# Hello, this is a quick test file.
# this is second line
# this is third line
# Out:
# Overwriting my_new_file.txt

# %%
with open ('my_new_file.txt', mode= 'r' ) as f:
    print(f.read())
# Out:
# Hello, this is a quick test file.
# this is second line
# this is third line

# %%
with open ('my_new_file.txt', mode= 'a' ) as f:
    f.write('\nforth line')

# %%
with open ('my_new_file.txt', mode= 'r' ) as f:
    print(f.readlines())
# Out:
# ['Hello, this is a quick test file.\n', 'this is second line\n', 'this is third line\n', 'forth line']

# %%
with open ('sfsfsfsfdsdf.txt' , mode ='w') as f :
    f.write("This is new file")
