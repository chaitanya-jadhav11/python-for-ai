# %%
d=2

# %%
d= "ff"

# %%
print (d)
# Out:
# ff

# %%
d = d + d

# %%
d
# Out:
# 'ffff'

# %%
type(d)
# Out:
# str

# %%
d= 3

# %%
type(d)
# Out:
# int

# %%
income =100
tax = 0.1
my_taxes = income * tax

# %%
my_taxes
# Out:
# 10.0
