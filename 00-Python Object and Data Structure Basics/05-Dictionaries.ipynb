# %% [markdown]
# Dictionaries

# %%
my_dict = {'key1':'val1', 'key2': 'val2'}

# %%
my_dict
# Out:
# {'key1': 'val1', 'key2': 'val2'}

# %%
my_dict.get('key1') # OR my_dict['key1']
# Out:
# 'val1'

# %%
my_dict['key1']
# Out:
# 'val1'

# %%
d = {'k1':123, 'k2': [0,1,2], 'k3' : {'nestedKey': 'val2'}}

# %%
d['k2'][1] # fecth nested ARRAy items
# Out:
# 1

# %%
d['k3']['nestedKey'] # fecth nested Dict items
# Out:
# 'val2'

# %%
d['k3'].get('nestedKey') # fecth nested Dict items
# Out:
# 'val2'

# %%
d['k3']['nestedKey'].upper() # IT will not update dicttionary value
# Out:
# 'VAL2'

# %%
d
# Out:
# {'k1': 123, 'k2': [0, 1, 2], 'k3': {'nestedKey': 'val2'}}

# %%
d1 = {'k1': ['a','b','c']}

# %%
letter =d1.get('k1')[2].upper()

# %%
letter
# Out:
# 'C'

# %%
d3= {'k1':100 , 'k2' : 200}

# %%
d3['k3'] = 300 # Add new key /values

# %%
d3['k3']
# Out:
# 300

# %%
d3['k3'] = 301  # Update value

# %%
d3['k3']
# Out:
# 301

# %%
d3.keys() # GEt vall keys
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d3.values() # GEt vall values
# Out:
# dict_values([100, 200, 301])

# %%
d3.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 301)])

# %%
d3
# Out:
# {'k1': 100, 'k2': 200, 'k3': 301}
