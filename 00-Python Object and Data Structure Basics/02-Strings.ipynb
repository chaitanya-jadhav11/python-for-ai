# %%
mystr = 'hi'

# %%
mystr = " I'm going to run"

# %%
mystr = "hello"

# %%
mystr[1]
# Out:
# 'e'

# %%
mystr[-1]
# Out:
# 'o'

# %%
mystr[0]
# Out:
# 'h'

# %%
mystr[-4]
# Out:
# 'e'

# %%
print (mystr + ' there ')
# Out:
# hello there

# %%
len (mystr)
# Out:
# 5

# %%
len ("hello there")
# Out:
# 11

# %%
s = 'Hello World'

# %%
s[2:]
# Out:
# 'llo World'

# %%
s[:3]
# Out:
# 'Hel'

# %%
s[3:5]
# Out:
# 'lo'

# %%
s[::]
# Out:
# 'Hello World'

# %%
s[::4]
# Out:
# 'Hor'

# %%
s[1:4:1]
# Out:
# 'ell'

# %%
s[::-1]
# Out:
# 'dlroW olleH'

# %%
name= "same"

# %%
# name[1]= 'Immutability' -error

# %%
name + " last name"
# Out:
# 'samelast name'

# %%
name = name + name

# %%
name
# Out:
# ''

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
'2' + '2'
# Out:
# '22'

# %%
x = 'Hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.split()
# Out:
# ['Hello', 'world']
