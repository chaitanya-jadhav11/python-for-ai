# %% [markdown]
# Set

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %% [markdown]
# Boolean

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
1==1
# Out:
# True

# %%
1>2
# Out:
# False

# %%
b = None

# %%
type(b)
# Out:
# NoneType
