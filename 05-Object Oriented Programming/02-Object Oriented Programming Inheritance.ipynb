# %%
class Animal:
    def __init__(self):
        print("Animal created")
        
    def whoAmI(self):
        print("Animal")

    def eat(self):
        print("Eating")

# %%
animal= Animal()
# Out:
# Animal created

# %%
animal.eat()
# Out:
# Eating

# %%
animal.whoAmI()
# Out:
# Animal

# %%
class Dog(Animal):
    def __init__(self):
        Animal.__init__(self)
        print("Dog created")

    def whoAmI(self):
        print("Dog")

    def bark(self):
        print("Woof!")

# %%
animal= Dog()
# Out:
# Animal created
# Dog created

# %%
animal.eat()
# Out:
# Eating

# %%
animal.whoAmI()
# Out:
# Dog

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name+' says Woof!'
    
class Cat:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name+' says Meow!'

# %%
niko = Dog('Niko')
felix = Cat('Felix')

print(niko.speak())
print(felix.speak())
# Out:
# Niko says Woof!
# Felix says Meow!

# %%
def pet_speak(pet):
    print(pet.speak())

pet_speak(niko)
pet_speak(felix)
# Out:
# Niko says Woof!
# Felix says Meow!

# %%
class Animal:
    def __init__(self):
        print("Animal created")

    def speak(self):
         raise NotImplementedError("Subclass must override ")

# %%
animal = Animal()
# Out:
# Animal created

# %%
animal.speak()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 animal.speak()
#
# Cell In[29], line 6, in Animal.speak(self)
#       5 def speak(self):
# ----> 6      raise NotImplementedError("Subclass must override ")
#
# NotImplementedError: Subclass must override

# %%
print(niko.speak())
print(felix.speak())
# Out:
# Niko says Woof!
# Felix says Meow!

# %% [markdown]
# <b>Special Methods </b>

# %%
class Book:
    def __init__(self, title, author, pages):
        print("A book is created")
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return "Title: %s, author: %s, pages: %s" %(self.title, self.author, self.pages)

    def __len__(self):
        return self.pages

    def __del__(self):
        print("A book is destroyed")

# %%
book = Book("Python Rocks!", "Jose Portilla", 159)

#Special Methods
print(book)
# Out:
# A book is created
# Title: Python Rocks!, author: Jose Portilla, pages: 159
